# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# import warnings
# warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection  import chi2
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %%
# Healthcare for all datasets

# %%
numerical = pd.read_csv('numerical.csv')
target = pd.read_csv('target.csv')
categorical = pd.read_csv('categorical.csv')

# %%
numerical
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
# ...

# %%
target
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
categorical
# Out:
#        STATE  CLUSTER HOMEOWNR GENDER  DATASRCE RFA_2R RFA_2A GEOCODE2  \
# 0         IL       36        H      F         3      L      E        C
# 1         CA       14        H      M         3      L      G        A
# 2         NC       43        U      M         3      L      E        C
# 3         CA       44        U      F         3      L      E        C
# 4         FL       16        H      F         3      L      F        A
# ...      ...      ...      ...    ...       ...    ...    ...      ...
# 95407  other       27        H      M         3      L      G        C
# 95408     TX       24        H      M         3      L      F        A
# 95409     MI       30        H      M         3      L      E        B
# 95410     CA       24        H      F         2      L      F        A
# 95411     NC       24        U      F         3      L      G        C
#
#       DOMAIN_A  DOMAIN_B  ODATEW_YR  ODATEW_MM  DOB_YR  DOB_MM  MINRDATE_YR  \
# ...

# %%
all = pd.concat((numerical,target),axis=1)
all.head()
# Out:
#    TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0      0  60.000000       5        9    0         0       39        34
# 1      1  46.000000       6        9   16         0       15        55
# 2      1  61.611649       3        1    2         0       20        29
# 3      0  70.000000       1        4    2         0       23        14
# 4      0  78.000000       3        2   60         1       28         9
#
#    WWIIVETS  LOCALGOV  STATEGOV  FEDGOV  WEALTH2  POP901  POP902  POP903  \
# 0        18        10         2       1        5     992     264     332
# 1        11         6         2       1        9    3611     940     998
# 2        33         6         8       1        1    7001    2040    2669
# 3        31         3         0       3        0     640     160     219
# 4        53        26         3       2        9    2520     627     761
#
#    POP90C1  POP90C2  POP90C3  POP90C4  POP90C5  ETH1  ETH2  ETH3  ETH4  ETH5  \
# ...

# %%
X = all.drop('TARGET_B',axis=1)
y = all['TARGET_B']

# %% [markdown]
# ### Get 20 Features and the target

# %%
#ørdinary Least Squares Regression model:
X_added_constant = sm.add_constant(X)
X_added_constant
# Out:
#        const  TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  \
# 0        1.0      0  60.000000       5        9    0         0       39
# 1        1.0      1  46.000000       6        9   16         0       15
# 2        1.0      1  61.611649       3        1    2         0       20
# 3        1.0      0  70.000000       1        4    2         0       23
# 4        1.0      0  78.000000       3        2   60         1       28
# ...      ...    ...        ...     ...      ...  ...       ...      ...
# 95407    1.0      1  61.611649       5        9    0        14       36
# 95408    1.0      1  48.000000       7        9    1         0       31
# 95409    1.0      1  60.000000       5        9    0         0       18
# 95410    1.0      0  58.000000       7        9    0         0       28
# 95411    1.0      2  80.000000       5        8    3         1       33
#
#        VIETVETS  WWIIVETS  LOCALGOV  STATEGOV  FEDGOV  WEALTH2  POP901  \
# ...

# %%
model = sm.OLS(y,X_added_constant).fit() #fit the model 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               TARGET_B   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     473.6
# Date:                Tue, 09 Aug 2022   Prob (F-statistic):               0.00
# Time:                        09:00:59   Log-Likelihood:                 54400.
# No. Observations:               95412   AIC:                        -1.082e+05
# Df Residuals:                   95095   BIC:                        -1.052e+05
# Df Model:                         316
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.008      0.287      0.774      -0.013       0.017
# ...

# %%
kbest = SelectKBest(chi2, k=20).fit_transform(X, y)
selected = pd.DataFrame(kbest)

# %%
# To check the scores
model = SelectKBest(chi2, k=20).fit(X, y)
df = pd.DataFrame(data = model.scores_, columns = ['score'])
df['Column'] = X.columns

df.sort_values(by = ['score'], ascending = False).head(30)
# Out:
#             score    Column
# 315  1.415081e+06  TARGET_D
# 311  5.277164e+05  CONTROLN
# 140  1.879840e+05       IC5
# 83   4.985561e+04       HV1
# 84   4.956107e+04       HV2
# 0    3.908707e+04     TCODE
# 133  2.689143e+04       MSA
# 13   1.716723e+04    POP901
# 137  2.921367e+03       IC2
# 14   2.811233e+03    POP902
# 303  2.756199e+03  RAMNTALL
# 139  2.751448e+03       IC4
# 110  2.620984e+03      HVP1
# 111  2.549992e+03      HVP2
# 136  2.448754e+03       IC1
# 138  2.415717e+03       IC3
# 15   2.166139e+03    POP903
# 112  2.132963e+03      HVP3
# 115  1.906878e+03      HVP6
# 304  1.883561e+03  NGIFTALL
# 113  1.472532e+03      HVP4
# 308  1.354815e+03  LASTGIFT
# 22   1.290384e+03      ETH2
# 129  1.245572e+03       RP1
# 300  1.178546e+03   NUMPROM
# 305  1.128177e+03  CARDGIFT
# 130  1.091241e+03       RP2
# 135  9.758750e+02       DMA
# 306  8.922378e+02  MINRAMNT
# 310  8.727221e+02   AVGGIFT

# %%
X = all[['CONTROLN','IC5','HV1','TCODE','MSA','POP901','RAMNTALL','HVP1','NGIFTALL','NUMPROM','CARDGIFT','MINRAMNT','AVGGIFT','DMA','LASTGIFT','ETH2','RP1','HVP2','HVP3','HVP6']]

# %%
fig, ax = plt.subplots(figsize=(70, 70))
sns.heatmap(X.corr(),annot=True, annot_kws={'size': 50})
# Out:
# <AxesSubplot:>

# %%
# no necessity to drop any variable

# %%
X.isna().sum()

# no NaN values
# Out:
# CONTROLN    0
# IC5         0
# HV1         0
# TCODE       0
# MSA         0
# POP901      0
# RAMNTALL    0
# HVP1        0
# NGIFTALL    0
# NUMPROM     0
# CARDGIFT    0
# MINRAMNT    0
# AVGGIFT     0
# DMA         0
# LASTGIFT    0
# ETH2        0
# RP1         0
# HVP2        0
# HVP3        0
# HVP6        0
# dtype: int64

# %%
X
# Out:
#        CONTROLN    IC5   HV1  TCODE     MSA  POP901  RAMNTALL  HVP1  NGIFTALL  \
# 0         95515  12883   479      0     0.0     992     240.0     2        31
# 1        148535  36175  5468      1  4480.0    3611      47.0    97         3
# 2         15078  11576   497      1     0.0    7001     202.0     0        27
# 3        172556  15130  1000      0  9340.0     640     109.0    10        16
# 4          7112   9836   576      0  5000.0    2520     254.0     0        37
# ...         ...    ...   ...    ...     ...     ...       ...   ...       ...
# 95407    184568  18807   988      1   380.0   27380      25.0     2         1
# 95408    122706  26538  1679      1  3360.0    1254      20.0    18         1
# 95409    189641  12178   376      1  4040.0     552      58.0     0         7
# 95410      4693  15948  2421      0  8735.0    1746     498.0    89        41
# 95411    185114  16699   938      2  9200.0    3935    3775.0     3        39
#
# ...

# %%
y = all['TARGET_B']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 95407    0
# 95408    0
# 95409    0
# 95410    1
# 95411    0
# Name: TARGET_B, Length: 95412, dtype: int64

# %% [markdown]
# ### Log Regression Classifier

# %%
# X/y Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(numerical, y, test_size=0.2)

# %%
# Normalize
# train test

transformer = MinMaxScaler().fit(X_train)
#Normalized X_train and X_test
X_train_normalized = transformer.transform(X_train)
X_test_normalized = transformer.transform(X_test)

#Making a DF for X_train_norm
X_train_norm = pd.DataFrame(X_train_normalized, columns = X_train.columns) 
X_train_norm.head()
# Out:
#       TCODE       AGE    INCOME   WEALTH1       HIT  MALEMILI   MALEVET  \
# 0  0.000000  0.624862  0.666667  1.000000  0.000000  0.000000  0.232323
# 1  0.000000  0.624862  0.666667  1.000000  0.000000  0.000000  0.171717
# 2  0.000014  0.624862  0.666667  1.000000  0.000000  0.000000  0.242424
# 3  0.000389  0.453608  0.666667  0.777778  0.000000  0.030612  0.383838
# 4  0.000000  0.453608  0.833333  0.777778  0.016598  0.000000  0.333333
#
#    VIETVETS  WWIIVETS  LOCALGOV  STATEGOV    FEDGOV   WEALTH2    POP901  \
# 0  0.363636  0.303030  0.056338  0.060606  0.011494  0.333333  0.073191
# 1  0.292929  0.717172  0.154930  0.020202  0.057471  1.000000  0.011925
# 2  0.656566  0.151515  0.140845  0.121212  0.022989  0.888889  0.013505
# 3  0.343434  0.222222  0.169014  0.020202  0.045977  0.222222  0.000020
# 4  0.505051  0.131313  0.154930  0.020202  0.034483  1.000000  0.070658
#
#      POP902    POP903   POP90C1   POP90C2   POP90C3   POP90C4   POP90C5  \
# ...

# %%
# dataframe for X_test_norm

X_test_norm = pd.DataFrame(X_test_normalized, columns = X_test.columns) 
X_test_norm.head()
# Out:
#       TCODE       AGE    INCOME   WEALTH1       HIT  MALEMILI   MALEVET  \
# 0  0.000389  0.624862  0.000000  0.111111  0.020747  0.000000  0.272727
# 1  0.000028  0.845361  0.500000  0.444444  0.045643  0.000000  0.444444
# 2  0.000028  0.624862  0.666667  1.000000  0.000000  0.010204  0.363636
# 3  0.000014  0.752577  0.333333  1.000000  0.045643  0.000000  0.292929
# 4  0.000000  0.360825  0.833333  0.777778  0.008299  0.000000  0.181818
#
#    VIETVETS  WWIIVETS  LOCALGOV  STATEGOV    FEDGOV   WEALTH2    POP901  \
# 0  0.444444  0.383838  0.140845  0.030303  0.057471  1.000000  0.007092
# 1  0.121212  0.595960  0.112676  0.101010  0.000000  0.444444  0.016363
# 2  0.636364  0.161616  0.169014  0.121212  0.149425  0.888889  0.012502
# 3  0.161616  0.353535  0.056338  0.010101  0.022989  1.000000  0.019980
# 4  0.313131  0.202020  0.253521  0.010101  0.022989  0.777778  0.022026
#
#      POP902    POP903  POP90C1   POP90C2   POP90C3   POP90C4   POP90C5  \
# ...

# %%
y_train
# Out:
# 92569    1
# 42786    1
# 70321    0
# 60415    0
# 30990    0
#         ..
# 71016    0
# 32198    0
# 31296    0
# 69775    0
# 62648    0
# Name: TARGET_B, Length: 76329, dtype: int64

# %%
#always reset index
y_train = y_train.reset_index(drop=True) 
y_test = y_test.reset_index(drop=True)

# %%
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state= 0)
classifier.fit(X_train,y_train)
# Out:
# C:\Users\egheb\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
classifier.score(X_train, y_train)
# Out:
# 0.9481848314533139

# %%
classifier.score(X_test, y_test)
# Out:
# 0.949483833778756

# %% [markdown]
# ## Treat for Imbalance

# %%
target.TARGET_B.value_counts()
# Out:
# 0    90569
# 1     4843
# Name: TARGET_B, dtype: int64

# %%
data = pd.concat([numerical, target.TARGET_B], axis=1)

# %%
#downsampling so we do not create artificial data 
from sklearn.utils import resample
#split (train) on 2 majority class 

category_0 = data[data['TARGET_B'] == 0]
category_1 = data[data['TARGET_B'] == 1]
print(len(category_0))
print(len(category_1))

#create a new DF category_0 by downsampling from 90569 to 4843
category_0_undersampled = resample(category_0, 
                                   replace=False, 
                                   n_samples = len(category_1))
print(len(category_0_undersampled))
# Out:
# 90569
# 4843
# 4843

# %%
# balanced data
print(category_0_undersampled.shape)
print(category_1.shape)
# Out:
# (4843, 316)
# (4843, 316)

# %%
data_downsampled = pd.concat([category_0_undersampled, category_1], axis=0)

# %%
# do another X/y split 
X = data_downsampled.drop(["TARGET_B"], axis=1)
y = data_downsampled["TARGET_B"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

num_train_minmax = transformer.transform(X_train)
num_test_minmax = transformer.transform(X_test)

classifier = LogisticRegression(random_state= 0)
classifier.fit(X_train,y_train)

print(classifier.score(X_train, y_train))
print(classifier.score(X_test, y_test))
# Out:
# 0.5488711453744494
# 0.5350949628406276
# C:\Users\egheb\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# results are not better

# %% [markdown]
# ## Upsampling

# %%
# Oversampling :

# %%
category_1_oversampled = resample(category_1, 
                                  replace=True, 
                                  n_samples = len(category_0))

print(category_0.shape)
print(category_1_oversampled.shape)
# Out:
# (90569, 316)
# (90569, 316)

# %%
data_up = pd.concat([category_0, category_1_oversampled], axis=0)

# %%
data_up['TARGET_B'].value_counts()
# Out:
# 0    90569
# 1    90569
# Name: TARGET_B, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

num_train_minmax = transformer.transform(X_train)
num_test_minmax = transformer.transform(X_test)

classifier = LogisticRegression(random_state= 0)
classifier.fit(X_train,y_train)

print(classifier.score(X_train, y_train))
print(classifier.score(X_test, y_test))
# Out:
# 0.5443281938325991
# 0.532204789430223
# C:\Users\egheb\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(category_0.shape)
print(category_1_oversampled.shape)
# Out:
# (90569, 316)
# (90569, 316)

# %% [markdown]
# ## random forest classification

# %%
X = data_up.drop(["TARGET_B"], axis=1)
y = data_up["TARGET_B"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_train_minmax = transformer.transform(X_train)
X_test_minmax = transformer.transform(X_test)
len(X_train_minmax)
# Out:
# 144910

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

clf = RandomForestClassifier(max_depth=5,            
                             min_samples_split=20,   
                             min_samples_leaf =20,  
                             max_samples=0.8,       
                             random_state = 42)

clf.fit(X_train_minmax, y_train)
print(clf.score(X_train_minmax, y_train))
print(clf.score(X_test_minmax , y_test))

y_pred = clf.predict(X_test_minmax)
display(y_test.value_counts())
display(confusion_matrix(y_test, y_pred))
# Out:
# 0.6160996480574149
# 0.618057855802142
# 1    18213
# 0    18015
# Name: TARGET_B, dtype: int64
# array([[11032,  6983],
#        [ 6854, 11359]], dtype=int64)

# %% [markdown]
# ## Random Forest Regressor

# %%
data_imbalanced_2 = pd.concat([numerical, target.TARGET_D,target.TARGET_B],axis=1)
data_imbalanced_2
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
# ...

# %%
# get the subset of those who made donations in both train and test

donations = data_imbalanced_2[data_imbalanced_2['TARGET_B']==1] #numerical data for the people that have donated 
X = data_imbalanced_2.drop(columns=['TARGET_B','TARGET_D'])
y = data_imbalanced_2['TARGET_D']

# %%
# Props to Chris!
def forest_2(df):
    
    
    # x - y - split
    
    features = df.drop(['TARGET_D'],axis=1)
    target = df['TARGET_D']
    
    
    # train - test - split
    
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25)
    
    
    # scaling Xtrain in scaler
    
    transformer = MinMaxScaler().fit(X_train)
    num_train_minmax = transformer.transform(X_train)
    num_test_minmax = transformer.transform(X_test)
    
    
    # fitting train set in model
    
    classifier = RandomForestRegressor(max_depth=5, # max number of questions
                             min_samples_split=20, # amount of rows still considered at every question
                             min_samples_leaf =20, # ultimate answer based on at least this many rows
                             max_samples=0.8) # fraction of original dataset
                             
    classifier.fit(X_train, y_train)
    
     
    # metrics
    
    score_1 = classifier.score(X_train, y_train)
    score_2 = classifier.score(X_test, y_test)
    
    
    # predictions
    
    pred = classifier.predict(X_test)
    
    return print('train',score_1,'\n''test',score_2,'\n''\n',
                 'predicted donation', np.mean(pred))

# %%
forest_2(donations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 forest_2(donations)
#
# Input In [63], in forest_2(df)
#      20 num_test_minmax = transformer.transform(X_test)
#      23 # fitting train set in model
# ---> 25 classifier = RandomForestRegressor(max_depth=5, # max number of questions
#      26                          min_samples_split=20, # amount of rows still considered at every question
#      27                          min_samples_leaf =20, # ultimate answer based on at least this many rows
#      28                          max_samples=0.8) # fraction of original dataset
#      30 classifier.fit(X_train, y_train)
#      33 # metrics
#
# NameError: name 'RandomForestRegressor' is not defined
